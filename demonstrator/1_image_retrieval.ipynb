# %% [markdown]
# # Image retrieval
#
# Match museum images with users' pictures.
#
# Methods:
#
#  * OpenCV - FLANN Matcher. It's not easy to define a similarity score that is reliable for all the matchings
#  * OpenCV - BF Matcher. Less performant than FLANN Matcher
#  * Tensorflow - DELF. Returns several false positives but the correct matched image, if available, gives significant results - the number of inliers (matching keypoints) are consistently higher. However there is no magic number for a similarity score.
#  * **CNN - Keras**. So far, the best option. Uses a convolutional neural network to extract features.
#
# Others (removed):
#  * OpenCV - Contours. Not reliable for images that include details of objects or landscape pictures of rooms.
#
#
# ### Imports

# %%
import cv2
import numpy as np
import glob , json
from matplotlib import pyplot as plt

# %% [markdown]
# ##  FLANN - OpenCV
#
# FLANN applied to images in two folders recursively.

# %%
def flann_percent(users_imgs_folder, catalogue_folder):
    """FLANN applied to images included in two folders. 
    Computes a siliarity score based on the proportion of good keypoints and the total numebr of keypoints.
    Returns a JSON file with the best matches.
    Example: flann_percent('images/user_imgs/','images/museum_imgs/')"""

    matches_list = []
    MIN_MATCH_COUNT = 800
    MIN_SIMILARITY_PERCENTAGE = 90
    for catalogue_img in glob.iglob(catalogue_folder+'*'):
        matches_dict = {}
        matches_dict["catalogue_img"] = catalogue_img
        for user_file in glob.iglob(users_imgs_folder+'*'):
            original = cv.imread(user_file,0)
            original = cv.cvtColor(original, cv.COLOR_GRAY2BGR)
            user_image = cv.imread(catalogue_img,0)
            user_image = cv.cvtColor(user_image, cv.COLOR_GRAY2BGR)

            index_params = dict(algorithm=1, trees=5)
            search_params = dict()

            sift = cv.xfeatures2d.SIFT_create()
            kp_1, desc_1 = sift.detectAndCompute(original, None)
            kp_2, desc_2 = sift.detectAndCompute(user_image, None)
            flann = cv.FlannBasedMatcher(index_params, search_params)
            matches = flann.knnMatch(desc_1, desc_2, k=2)
            good_points = []
            for m, n in matches:
                if m.distance > 0.7*n.distance:
                    good_points.append(m)

            number_keypoints = len(kp_1) if len(kp_1) >= len(kp_2) else len(kp_2)
            percentage_similarity = len(good_points) / number_keypoints * 100
            
            print("User: " + user_file)
            print("Catalogue: " + catalogue_img)
            print("Similarity: " + str(int(percentage_similarity)) + "\n")
            
            if percentage_similarity >= MIN_SIMILARITY_PERCENTAGE and len(good_points)>MIN_MATCH_COUNT:
                print("Lenght points:", len(good_points))
                print(len(good_points) , len(kp_1) , len(kp_2))
                matches_dict[user_file] = [percentage_similarity, len(good_points)]
            
            if len(good_points)>MIN_MATCH_COUNT:
                src_pts = np.float32([ kp_1[m.queryIdx].pt for m in good_points ]).reshape(-1,1,2)
                dst_pts = np.float32([ kp_2[m.trainIdx].pt for m in good_points ]).reshape(-1,1,2)
                M, mask = cv.findHomography(src_pts, dst_pts, cv.RANSAC,5.0)
                matchesMask = mask.ravel().tolist()
                h,w,d = original.shape
                pts = np.float32([ [0,0],[0,h-1],[w-1,h-1],[w-1,0] ]).reshape(-1,1,2)
                dst = cv.perspectiveTransform(pts,M)
                img2 = cv.polylines(user_image,[np.int32(dst)],True,255,3, cv.LINE_AA)
                draw_params = dict(matchColor = (0,255,0), # draw matches in green color
                   singlePointColor = None,
                   matchesMask = matchesMask, # draw only inliers
                   flags = 2)
                img3 = cv.drawMatches(original,kp_1,img2,kp_2,good_points,None,**draw_params)
                plt.imshow(img3, 'gray'),plt.show()
                
            else:
                print( "Not enough matches are found - {}/{}".format(len(good_points), MIN_MATCH_COUNT) )
                matchesMask = None
            

    
        matches_list.append(matches_dict)

    with open('images_matching.json', 'w', encoding='utf-8') as outfile:
        json.dump(matches_list, outfile, ensure_ascii=False, indent=1)

# %% [markdown]
# FLANN applied recursively to images in two folders with Lowe ratio test (to select the good keypoints)

# %%
def flann_lowe(users_imgs_folder, catalogue_folder):
    """FLANN applied to images included in two folders. 
    Computes a siliarity score based on the Lowe's ratio.
    Returns: the plot with the best matches.
    Example: flann_lowe('images/user_imgs/','images/museum_imgs/')"""
    for catalogue_img in glob.iglob(catalogue_folder+'*'):
        for user_file in glob.iglob(users_imgs_folder+'*'):
            img1 = cv.imread(catalogue_img, cv.COLOR_BGR2GRAY)  # queryImage
            img2 = cv.imread(user_file, cv.COLOR_BGR2GRAY)  # trainImage


            # Initiate SIFT with FLANN parameters detector
            sift = cv.SIFT_create()

            # find the keypoints and descriptors with SIFT
            kp1, des1 = sift.detectAndCompute(img1,None)
            kp2, des2 = sift.detectAndCompute(img2,None)

            # FLANN parameters
            FLANN_INDEX_KDTREE = 1
            index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
            search_params = dict(checks=50)
            flann = cv.FlannBasedMatcher(index_params,search_params)
            matches = flann.knnMatch(des1,des2,k=2)

            # Need to draw only good matches, so create a mask
            matchesMask = [[0,0] for i in range(len(matches))]

            # ratio test as per Lowe's paper
            good = 0
            for i,(m,n) in enumerate(matches):
                if m.distance < 0.5*n.distance:
                    good +=1
                    matchesMask[i]=[1,0]
            draw_params = dict(matchColor = (0,255,0),
                               singlePointColor = (255,0,0),
                               matchesMask = matchesMask,
                               flags = cv.DrawMatchesFlags_DEFAULT)
            if good> 10:
                im3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,matches,None,**draw_params)

                match_title= str(good)+ ' good points - kp1:'+(str(len(kp1))) + ' kp2:',(str(len(kp2)))
                print('cat:',catalogue_img,'\nuser:', user_file, '\n',match_title)
                plt.imshow(im3),plt.show()

# %% [markdown]
# FLANN applied to two images only.

# %%
def flann_(catalogue_img,user_file):
    """FLANN applied to two images. 
    Computes a siliarity score based on the Lowe's ratio.
    Returns: the plot with the best matches.
    Example: flann_('images/im1.jpg','images/im2.jpg')"""
    img1 = cv.imread(catalogue_img, cv.COLOR_BGR2GRAY)  # queryImage
    img2 = cv.imread(user_file, cv.COLOR_BGR2GRAY)  # trainImage


    # Initiate SIFT with FLANN parameters detector
    sift = cv.SIFT_create()

    # find the keypoints and descriptors with SIFT
    kp1, des1 = sift.detectAndCompute(img1,None)
    kp2, des2 = sift.detectAndCompute(img2,None)

    # FLANN parameters
    FLANN_INDEX_KDTREE = 1
    index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
    search_params = dict(checks=50)
    flann = cv.FlannBasedMatcher(index_params,search_params)
    matches = flann.knnMatch(des1,des2,k=2)

    # Need to draw only good matches, so create a mask
    matchesMask = [[0,0] for i in range(len(matches))]

    # ratio test as per Lowe's paper
    good = 0
    for i,(m,n) in enumerate(matches):
        if m.distance < 0.75*n.distance:
            good +=1
            matchesMask[i]=[1,0]
    draw_params = dict(matchColor = (0,255,0),
                       singlePointColor = (255,0,0),
                       matchesMask = matchesMask,
                       flags = cv.DrawMatchesFlags_DEFAULT)
    
    im3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,matches,None,**draw_params)

    match_title= str(good)+ ' good points - kp1:'+(str(len(kp1))) + ' kp2:',(str(len(kp2)))
    print('cat:',catalogue_img,'\nuser:', user_file, '\n',match_title)
    plt.imshow(im3),plt.show()

# %% [markdown]
# ## Brute-force Matcher - OpenCV
#
# BF applied respectively, to two images only and to images in two folders (recursively).

# %%
def bf_(im1, im2):
    """ Brute forse applied on two images. 
    Returns: the plot with all the matches.
    Example: bf_('images/im1.jpg','images/im2.jpg')
    """
    img1 = cv.imread('images/dmh_test/test.jpg', cv.COLOR_BGR2GRAY)  # queryImage
    img2 = cv.imread('images/ig_test/925902_651302864947190_1364658590_n.jpg?_nc_ht=scontent-arn2-1.cdninstagram.com&_nc_cat=102&_nc_ohc=6HwAxf1g7VQAX8tOgkL&tp=1&oh=3bd2381ac6533461890d7b25cd09dc06&oe=603D5C88', cv.COLOR_BGR2GRAY)  # trainImage

    orb = cv.ORB_create()
    kp1, des1 = orb.detectAndCompute(img1, None)
    kp2, des2 = orb.detectAndCompute(img2, None)

    bf = cv.BFMatcher(cv.NORM_HAMMING, crossCheck=True)
    matches = bf.match(des1, des2)

    # Sort them in the order of their distance.
    matches = sorted(matches, key=lambda x: x.distance)
    img3 = cv.drawMatches(img1, kp1, img2, kp2, matches, None, flags=2)

    plt.imshow(img3)
    plt.show()
    
def brute_force(im1, im2):
    """ Brute forse applied on two images. Use SIFT and knnMatcher 
    Returns: the plot with all the matches.
    Example: brute_force('images/im1.jpg','images/im2.jpg')
    """
    img1 = cv.imread(im1, cv.COLOR_BGR2GRAY)  # queryImage
    img2 = cv.imread(im2, cv.COLOR_BGR2GRAY)  # trainImage

    # Initiate SIFT detector
    sift = cv.SIFT_create()

    # find the keypoints and descriptors with SIFT
    kp1, des1 = sift.detectAndCompute(img1,None)
    kp2, des2 = sift.detectAndCompute(img2,None)

    # BFMatcher with default params
    bf = cv.BFMatcher()
    matches = bf.knnMatch(des1,des2, k=2)

    # Apply ratio test
    good = []
    for m,n in matches:
        if m.distance < 0.75*n.distance:
            good.append([m])

    # cv.drawMatchesKnn expects list of lists as matches.
    img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,flags=2,outImg=im3)

    plt.imshow(img3),plt.show()

# %% [markdown]
# ## Tensorflow DELF
#
# Load the neural model.

# %%
import tensorflow_hub as hub
delf = hub.load('https://tfhub.dev/google/delf/1').signatures['default']

# %% [markdown]
# Functions to extract inliers from images.

# %%
from absl import logging

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image, ImageOps
from PIL import ImageFile
from scipy.spatial import cKDTree
from skimage.feature import plot_matches
from skimage.measure import ransac
from skimage.transform import AffineTransform
from six import BytesIO

import glob , json
import tensorflow as tf


from six.moves.urllib.request import urlopen

def download_and_resize(url, new_width=256, new_height=256):
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    image = Image.open(url)
    image = ImageOps.fit(image, (new_width, new_height), Image.ANTIALIAS)
    return image

def run_delf(image):
    np_image = np.array(image)
    float_image = tf.image.convert_image_dtype(np_image, tf.float32)

    return delf(
        image=float_image,
        score_threshold=tf.constant(100.0),
        image_scales=tf.constant([0.25, 0.3536, 0.5, 0.7071, 1.0, 1.4142, 2.0]),
        max_feature_num=tf.constant(1000))

def match_images(image1, image2, result1, result2):
    distance_threshold = 0.8

    # Perform geometric verification using RANSAC.
    try:
        # Read features.
        num_features_1 = result1['locations'].shape[0]
        num_features_2 = result2['locations'].shape[0]


        # Find nearest-neighbor matches using a KD tree.
        d1_tree = cKDTree(result1['descriptors'])
        _, indices = d1_tree.query(
          result2['descriptors'],
          distance_upper_bound=distance_threshold)

        # Select feature locations for putative matches.
        locations_2_to_use = np.array([
          result2['locations'][i,]
          for i in range(num_features_2)
          if indices[i] != num_features_1
        ])
        locations_1_to_use = np.array([
          result1['locations'][indices[i],]
          for i in range(num_features_2)
          if indices[i] != num_features_1
        ])

        _, inliers = ransac(
          (locations_1_to_use, locations_2_to_use),
          AffineTransform,
          min_samples=3,
          residual_threshold=20,
          max_trials=1000)

        print("Loaded image cat %d features" % num_features_1)
        print("Loaded image user %d features" % num_features_2)
        print('Found %d inliers' % sum(inliers))

        # Visualize correspondences.
        #_, ax = plt.subplots()
        #inlier_idxs = np.nonzero(inliers)[0]
        #plot_matches(ax,image1,image2,locations_1_to_use,locations_2_to_use,np.column_stack((inlier_idxs, inlier_idxs)),matches_color='b')
        #ax.axis('off')
        #title_plot = 'inliers:'+str(sum(inliers))
        #ax.set_title(title_plot)
        return sum(inliers)
    except:
        return 0

# %% [markdown]
# Apply DELF to images in two folders, save results in a JSON.

# %%
def delf_(catalogue_folder, user_folder):  
    """
    Match images from two folders using DELF. 
    Returns: a JSON file **for each image in the first folder** (`<image_name>.json`), 
    including the list of matched images ranked by the number of matched inliers (`<image_name> : <int>`).
    Example: delf_("images/dmh/", "images/ig_2000/")
    """
    for catalogue_img in glob.iglob(catalogue_folder+'*'):
        f_name = catalogue_img.split('.jp')[0].split(catalogue_folder)[1]
        match_dict = {}
        match_dict['catalogue_img'] = catalogue_img
        image1 = download_and_resize(catalogue_img)
        try:
            result1 = run_delf(image1)
            for user_file in glob.iglob(user_folder+'*'):     
                image2 = download_and_resize(user_file)
                try:        
                    result2 = run_delf(image2) 
                    img_mtc = match_images(image1, image2, result1, result2)

                    if img_mtc > 0:  
                        match_dict[user_file] = int(img_mtc)

                except Exception as e:
                    match_dict['error'] = 'True'  
        except Exception as e:
            pass 
        with open('delf/delf_'+f_name+'.json', 'w', encoding='utf-8') as outfile:
            json.dump(match_dict, outfile, ensure_ascii=False, indent=1)

# %%
delf_("GAM_catalogue_images/", "GAM_instagram_images/")
# Out:
# Loaded image cat 276 features
# Loaded image user 155 features
# Found 8 inliers
# Loaded image cat 276 features
# Loaded image user 79 features
# Loaded image cat 276 features
# Loaded image user 130 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 137 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 120 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 185 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 100 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 153 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 91 features
# Loaded image cat 276 features
# Loaded image user 101 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 70 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 61 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 51 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 73 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 123 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 144 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 75 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 102 features
# Loaded image cat 276 features
# Loaded image user 63 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 100 features
# Found 12 inliers
# Loaded image cat 276 features
# Loaded image user 113 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 187 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 190 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 102 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 136 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 118 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 146 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 105 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 193 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 156 features
# Found 9 inliers
# Loaded image cat 276 features
# Loaded image user 97 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 109 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 199 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 197 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 32 features
# Loaded image cat 276 features
# Loaded image user 195 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 66 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 54 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 87 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 94 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 125 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 135 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 128 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 113 features
# Loaded image cat 276 features
# Loaded image user 136 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 161 features
# Loaded image cat 276 features
# Loaded image user 75 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 164 features
# Loaded image cat 276 features
# Loaded image user 76 features
# Loaded image cat 276 features
# Loaded image user 103 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 88 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 117 features
# Found 9 inliers
# Loaded image cat 276 features
# Loaded image user 102 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 91 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 144 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 206 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 69 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 153 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 89 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 133 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 77 features
# Loaded image cat 276 features
# Loaded image user 203 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 85 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 96 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 152 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 126 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 65 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 111 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 160 features
# Found 9 inliers
# Loaded image cat 276 features
# Loaded image user 68 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 120 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 119 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 124 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 125 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 216 features
# Found 10 inliers
# Loaded image cat 276 features
# Loaded image user 123 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 163 features
# Found 11 inliers
# Loaded image cat 276 features
# Loaded image user 52 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 126 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 151 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 135 features
# Found 10 inliers
# Loaded image cat 276 features
# Loaded image user 126 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 181 features
# Found 8 inliers
# Loaded image cat 276 features
# Loaded image user 120 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 50 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 180 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 144 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 91 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 173 features
# Loaded image cat 276 features
# Loaded image user 181 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 132 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 108 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 122 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 134 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 38 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 143 features
# Loaded image cat 276 features
# Loaded image user 84 features
# Loaded image cat 276 features
# Loaded image user 104 features
# Loaded image cat 276 features
# Loaded image user 141 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 129 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 141 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 47 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 96 features
# Loaded image cat 276 features
# Loaded image user 73 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 116 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 96 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 101 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 94 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 88 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 204 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 95 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 135 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 47 features
# Loaded image cat 276 features
# Loaded image user 165 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 47 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 102 features
# Loaded image cat 276 features
# Loaded image user 111 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 97 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 56 features
# Loaded image cat 276 features
# Loaded image user 146 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 70 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 158 features
# Found 8 inliers
# Loaded image cat 276 features
# Loaded image user 85 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 160 features
# Found 12 inliers
# Loaded image cat 276 features
# Loaded image user 86 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 106 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 111 features
# Found 13 inliers
# Loaded image cat 276 features
# Loaded image user 109 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 48 features
# Loaded image cat 276 features
# Loaded image user 94 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 88 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 191 features
# Found 8 inliers
# Loaded image cat 276 features
# Loaded image user 115 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 132 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 102 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 54 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 55 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 58 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 106 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 182 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 57 features
# Loaded image cat 276 features
# Loaded image user 99 features
# Loaded image cat 276 features
# Loaded image user 71 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 106 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 86 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 94 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 115 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 99 features
# Loaded image cat 276 features
# Loaded image user 129 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 152 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 140 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 93 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 201 features
# Loaded image cat 276 features
# Loaded image user 109 features
# Loaded image cat 276 features
# Loaded image user 102 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 85 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 125 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 154 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 83 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 103 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 98 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 207 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 56 features
# Loaded image cat 276 features
# Loaded image user 57 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 236 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 98 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 125 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 94 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 46 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 124 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 193 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 109 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 133 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 114 features
# Loaded image cat 276 features
# Loaded image user 85 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 52 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 102 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 147 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 157 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 120 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 85 features
# Loaded image cat 276 features
# Loaded image user 269 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 61 features
# Loaded image cat 276 features
# Loaded image user 142 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 89 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 88 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 117 features
# Found 11 inliers
# Loaded image cat 276 features
# Loaded image user 100 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 98 features
# Loaded image cat 276 features
# Loaded image user 134 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 148 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 95 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 125 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 70 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 80 features
# Loaded image cat 276 features
# Loaded image user 212 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 66 features
# Loaded image cat 276 features
# Loaded image user 103 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 146 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 68 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 93 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 93 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 178 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 77 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 104 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 73 features
# Loaded image cat 276 features
# Loaded image user 110 features
# Found 11 inliers
# Loaded image cat 276 features
# Loaded image user 29 features
# Loaded image cat 276 features
# Loaded image user 199 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 143 features
# Found 8 inliers
# Loaded image cat 276 features
# Loaded image user 209 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 119 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 134 features
# Found 11 inliers
# Loaded image cat 276 features
# Loaded image user 100 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 169 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 61 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 110 features
# Loaded image cat 276 features
# Loaded image user 72 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 111 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 94 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 154 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 203 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 107 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 115 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 98 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 100 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 57 features
# Loaded image cat 276 features
# Loaded image user 133 features
# Found 8 inliers
# Loaded image cat 276 features
# Loaded image user 106 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 123 features
# Loaded image cat 276 features
# Loaded image user 128 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 96 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 88 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 93 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 99 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 110 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 102 features
# Loaded image cat 276 features
# Loaded image user 117 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 119 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 106 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 20 features
# Loaded image cat 276 features
# Loaded image user 126 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 96 features
# Loaded image cat 276 features
# Loaded image user 111 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 118 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 57 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 108 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 142 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 121 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 171 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 122 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 122 features
# Loaded image cat 276 features
# Loaded image user 151 features
# Found 9 inliers
# Loaded image cat 276 features
# Loaded image user 115 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 135 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 70 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 61 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 66 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 78 features
# Loaded image cat 276 features
# Loaded image user 147 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 159 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 92 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 180 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 101 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 90 features
# Found 8 inliers
# Loaded image cat 276 features
# Loaded image user 108 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 105 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 120 features
# Found 10 inliers
# Loaded image cat 276 features
# Loaded image user 68 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 129 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 140 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 130 features
# Found 9 inliers
# Loaded image cat 276 features
# Loaded image user 85 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 101 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 71 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 61 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 150 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 76 features
# Loaded image cat 276 features
# Loaded image user 181 features
# Loaded image cat 276 features
# Loaded image user 85 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 104 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 74 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 139 features
# Found 8 inliers
# Loaded image cat 276 features
# Loaded image user 176 features
# Found 8 inliers
# Loaded image cat 276 features
# Loaded image user 139 features
# Loaded image cat 276 features
# Loaded image user 187 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 81 features
# Found 8 inliers
# Loaded image cat 276 features
# Loaded image user 211 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 157 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 104 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 92 features
# Found 8 inliers
# Loaded image cat 276 features
# Loaded image user 102 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 144 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 100 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 92 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 115 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 144 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 92 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 63 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 115 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 40 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 66 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 49 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 182 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 196 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 170 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 56 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 57 features
# Loaded image cat 276 features
# Loaded image user 122 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 131 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 111 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 63 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 134 features
# Found 11 inliers
# Loaded image cat 276 features
# Loaded image user 225 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 105 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 160 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 114 features
# Loaded image cat 276 features
# Loaded image user 112 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 64 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 88 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 88 features
# Loaded image cat 276 features
# Loaded image user 146 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 126 features
# Found 9 inliers
# Loaded image cat 276 features
# Loaded image user 67 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 196 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 62 features
# Loaded image cat 276 features
# Loaded image user 84 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 115 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 124 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 89 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 119 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 161 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 122 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 124 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 93 features
# Found 7 inliers
# Loaded image cat 276 features
# Loaded image user 47 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 79 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 56 features
# Loaded image cat 276 features
# Loaded image user 163 features
# Found 6 inliers
# Loaded image cat 276 features
# Loaded image user 55 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 59 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 123 features
# Found 5 inliers
# Loaded image cat 276 features
# Loaded image user 99 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 103 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 67 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 194 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 122 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 105 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 57 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 91 features
# Loaded image cat 276 features
# Loaded image user 136 features
# Found 4 inliers
# Loaded image cat 276 features
# Loaded image user 92 features
# Found 3 inliers
# Loaded image cat 276 features
# Loaded image user 133 features
# Loaded image cat 276 features
# Loaded image user 81 features
# Found 6 inliers
# Loaded image cat 49 features
# Loaded image user 91 features
# Loaded image cat 49 features
# Loaded image user 67 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 130 features
# Loaded image cat 49 features
# Loaded image user 148 features
# Loaded image cat 49 features
# Loaded image user 65 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 112 features
# Found 7 inliers
# Loaded image cat 49 features
# Loaded image user 82 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 140 features
# Loaded image cat 49 features
# Loaded image user 73 features
# Loaded image cat 49 features
# Loaded image user 76 features
# Found 6 inliers
# Loaded image cat 49 features
# Loaded image user 70 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 102 features
# Loaded image cat 49 features
# Loaded image user 187 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 193 features
# Loaded image cat 49 features
# Loaded image user 82 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 85 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 111 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 195 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 94 features
# Loaded image cat 49 features
# Loaded image user 128 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 34 features
# Found 8 inliers
# Loaded image cat 49 features
# Loaded image user 103 features
# Loaded image cat 49 features
# Loaded image user 98 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 117 features
# Found 6 inliers
# Loaded image cat 49 features
# Loaded image user 69 features
# Found 6 inliers
# Loaded image cat 49 features
# Loaded image user 89 features
# Loaded image cat 49 features
# Loaded image user 99 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 203 features
# Found 6 inliers
# Loaded image cat 49 features
# Loaded image user 109 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 40 features
# Loaded image cat 49 features
# Loaded image user 89 features
# Loaded image cat 49 features
# Loaded image user 151 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 56 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 89 features
# Loaded image cat 49 features
# Loaded image user 73 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 62 features
# Loaded image cat 49 features
# Loaded image user 125 features
# Loaded image cat 49 features
# Loaded image user 33 features
# Loaded image cat 49 features
# Loaded image user 124 features
# Found 6 inliers
# Loaded image cat 49 features
# Loaded image user 134 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 38 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 66 features
# Loaded image cat 49 features
# Loaded image user 116 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 66 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 81 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 146 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 73 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 65 features
# Loaded image cat 49 features
# Loaded image user 106 features
# Loaded image cat 49 features
# Loaded image user 73 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 79 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 48 features
# Found 11 inliers
# Loaded image cat 49 features
# Loaded image user 74 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 87 features
# Loaded image cat 49 features
# Loaded image user 65 features
# Loaded image cat 49 features
# Loaded image user 82 features
# Loaded image cat 49 features
# Loaded image user 94 features
# Found 12 inliers
# Loaded image cat 49 features
# Loaded image user 94 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 100 features
# Loaded image cat 49 features
# Loaded image user 120 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 96 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 114 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 72 features
# Loaded image cat 49 features
# Loaded image user 142 features
# Loaded image cat 49 features
# Loaded image user 59 features
# Found 6 inliers
# Loaded image cat 49 features
# Loaded image user 132 features
# Loaded image cat 49 features
# Loaded image user 171 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 85 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 108 features
# Found 7 inliers
# Loaded image cat 49 features
# Loaded image user 65 features
# Loaded image cat 49 features
# Loaded image user 58 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 78 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 89 features
# Loaded image cat 49 features
# Loaded image user 72 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 145 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 128 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 80 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 103 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 109 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 184 features
# Found 8 inliers
# Loaded image cat 49 features
# Loaded image user 56 features
# Loaded image cat 49 features
# Loaded image user 65 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 84 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 137 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 73 features
# Loaded image cat 49 features
# Loaded image user 138 features
# Loaded image cat 49 features
# Loaded image user 72 features
# Loaded image cat 49 features
# Loaded image user 169 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 61 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 123 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 112 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 152 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 37 features
# Loaded image cat 49 features
# Loaded image user 33 features
# Loaded image cat 49 features
# Loaded image user 106 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 91 features
# Loaded image cat 49 features
# Loaded image user 144 features
# Loaded image cat 49 features
# Loaded image user 96 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 98 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 93 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 71 features
# Loaded image cat 49 features
# Loaded image user 47 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 118 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 133 features
# Loaded image cat 49 features
# Loaded image user 108 features
# Found 8 inliers
# Loaded image cat 49 features
# Loaded image user 57 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 201 features
# Found 3 inliers
# Loaded image cat 49 features
# Loaded image user 43 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 110 features
# Found 5 inliers
# Loaded image cat 49 features
# Loaded image user 134 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 66 features
# Loaded image cat 49 features
# Loaded image user 110 features
# Loaded image cat 49 features
# Loaded image user 121 features
# Loaded image cat 49 features
# Loaded image user 59 features
# Found 4 inliers
# Loaded image cat 49 features
# Loaded image user 85 features
# Found 3 inliers
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-8b51ac8a6518> in <module>
# ----> 1 delf_("GAM_catalogue_images/", "GAM_instagram_images/")
#
# <ipython-input-14-9da57c51cea0> in delf_(catalogue_folder, user_folder)
#      16                 image2 = download_and_resize(user_file)
#      17                 try:
# ---> 18                     result2 = run_delf(image2)
#      19                     img_mtc = match_images(image1, image2, result1, result2)
#      20
#
# <ipython-input-11-6efa075d5103> in run_delf(image)
#      27     float_image = tf.image.convert_image_dtype(np_image, tf.float32)
#      28
# ---> 29     return delf(
#      30         image=float_image,
#      31         score_threshold=tf.constant(100.0),
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    1653       TypeError: If the arguments do not match the function's signature.
#    1654     """
# -> 1655     return self._call_impl(args, kwargs)
#    1656
#    1657   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/wrap_function.py in _call_impl(self, args, kwargs, cancellation_manager)
#     244       return self._call_flat(args, self.captured_inputs)
#     245     else:
# --> 246       return super(WrappedFunction, self)._call_impl(
#     247           args, kwargs, cancellation_manager)
#     248
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1671             raise structured_err
#    1672
# -> 1673       return self._call_with_flat_signature(args, kwargs, cancellation_manager)
#    1674
#    1675   def _call_with_flat_signature(self, args, kwargs, cancellation_manager):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_with_flat_signature(self, args, kwargs, cancellation_manager)
#    1720                         "got {} ({})".format(self._flat_signature_summary(), i,
#    1721                                              type(arg).__name__, str(arg)))
# -> 1722     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1723
#    1724   def _call_with_structured_signature(self, args, kwargs, cancellation_manager):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Apply FLANN on top of DELF to lower the number of false positives (Spoiler alert, no good results).

# %%
# 
def flann_on_delf(delf_matches_folder):
    """
    Try out flann on the output of images matches with DELF (stored in a folder as JSON file) 
    - to restrict the number of false positives when the number of inliers is high.
    Returns: the plot of the good keypoints matched between images.
    Example: flann_on_delf("images/delf_results/")
    """
    for delf_file in glob.iglob(delf_matches_folder+'*.json'):
        with open(delf_file, 'r', encoding='utf-8') as delf_match:
            data_delf = json.load(delf_match)
            artefact = data_delf['catalogue_img']
            for img_ig, val in data_delf.items():
                if type(val) == int and val > 15:
                    #f, axarr = plt.subplots(2,2)
                    #axarr[0,0].imshow(cv.imread(artefact))
                    #axarr[0,0].set_title(val)
                    #axarr[0,1].imshow(cv.imread(img_ig))

                    flann_(artefact, img_ig)

# %% [markdown]
# ## CNN - Keras
#
# source: [https://towardsdatascience.com/build-an-image-search-engine-using-python-ad181e76441b](https://towardsdatascience.com/build-an-image-search-engine-using-python-ad181e76441b)

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

class FeatureExtractor:
    def __init__(self):
        # Use VGG-16 as the architecture and ImageNet for the weight
        base_model = VGG16(weights='imagenet')
        # Customize the model to return features from fully-connected layer
        self.model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)
    
    def extract(self, img):
        img = img.resize((224, 224))
        img = img.convert('RGB')
        # Reformat the image
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        # Extract Features
        feature = self.model.predict(x)[0]
        return feature / np.linalg.norm(feature)

# %%
fe = FeatureExtractor()

def extract_features_imgs(folder_name):
    """
    Extract features from images stored in "folder_name" using CNN. 
    Returns a numpy array stored in a .npy file for each image.
    Example: features , img_paths = extract_features_imgs("images/ig")
    """
    features = []
    img_paths = []

    for img_path in sorted(Path(folder_name).glob("*")):
            print(img_path)  # e.g., ./static/img/xxx.jpg
            feature = fe.extract(img=Image.open(img_path))
            feature_path = Path("images_feature") / (img_path.stem + ".npy")  # e.g., ./static/feature/xxx.npy
            np.save(feature_path, feature)

    for feature_path in Path("images_feature").glob("*.npy"):
        features.append(np.load(feature_path))
        img_paths.append(Path(folder_name) / (feature_path.stem ))

    features = np.array(features)
    return features , img_paths

# %%
# features , img_paths = extract_features_imgs("images/ig")

# %%
def query_img(img_file, features, img_paths):
    """
    Extract features from a query image "img_file" using CNN 
    and retrieves the best matches among the images previously matched ("features"). 
    Returns a numpy array stored in a .npy file for each image.
    Example: features , img_paths = extract_features_imgs("images/ig")
    """
    img = Image.open(img_file)
    # Extract its features
    query = fe.extract(img)
    dists = np.linalg.norm(features-query, axis=1)  # L2 distances to features
    ids = np.argsort(dists)[:30]  # Top 30 results
    scores = [(dists[id], img_paths[id]) for id in ids]
    return scores

# %% [markdown]
# #### Save results

# %%
from collections import defaultdict
import os

def save_cnn(input_images_folder, features, img_paths, output_json):
    """
    Example: Match all the images in two folders with Keras. 
    Save best matches in a JSON file. 
    features , img_paths = extract_features_imgs("images/ig")
    save_cnn("images/dmh/", features, img_paths, "dmh_ig_images_matching_cnn.json")
    outpt_json : { catalogue_img : [str(matched_img), float(similarity_score)] }
    """
    matches_dict = defaultdict(list)

    for catalogue_img in glob.iglob(input_images_folder+'*'):
        scores = query_img(catalogue_img, features, img_paths)
        for a in range(5*6):
            score = scores[a]
            similarity_score = score[0]
            if similarity_score <= 0.93:
                path = 'images/ig/'
                for i in os.listdir(path):
                    if os.path.isfile(os.path.join(path,i)) and str(score[1])[len(path)+1:] in i:
                        matched_img = path+i
                        matches_dict[catalogue_img].append( [matched_img, str(similarity_score)] )

    matches_dict = dict(matches_dict)

    with open(output_json, 'w', encoding='utf-8') as outfile:
            json.dump(matches_dict, outfile, ensure_ascii=False, indent=1)

# %%
# save_cnn("images/dmh/", features, img_paths, "images/dmh_ig_images_matching_cnn.json")

# %% [markdown]
# Plot the 30 best matches for a query image. Results with euclidean distance < .93 seem reliable (very conservative to avoid false positives).

# %%
import os
scores = query_img("images/dmh/wsi-imageoptim-etakortti-22242-320x422.jpg", features, img_paths)

axes=[]
fig=plt.figure(figsize=(8,8))
for a in range(5*6):
    score = scores[a]
    axes.append(fig.add_subplot(5, 6, a+1))
    subplot_title=str(score[0])
    axes[-1].set_title(subplot_title)  
    plt.axis('off')
    path = 'images/ig/'
    for i in os.listdir(path):
        if os.path.isfile(os.path.join(path,i)) and str(score[1])[len(path)+1:] in i:
            plt.imshow(Image.open(path+i))
fig.tight_layout()
plt.show()
